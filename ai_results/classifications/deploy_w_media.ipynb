# %%
# Import libraries
import pandas as pd

# Read in data
media_df = pd.read_csv('../../output/media.csv', low_memory=False)
deplo_df = pd.read_csv('../../output/deployments.csv')

# %%
merged_df = pd.merge(deplo_df, media_df, how='right', on='deploymentID')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229286 entries, 0 to 229285
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   deploymentID           66530 non-null   object
#  1   locationID             0 non-null       object
#  2   locationName           0 non-null       object
#  3   latitude               0 non-null       float64
#  4   longitude              0 non-null       float64
#  5   coordinateUncertainty  0 non-null       float64
#  6   deploymentStart        0 non-null       float64
#  7   deploymentEnd          0 non-null       float64
#  8   setupBy                0 non-null       object
#  9   cameraID               0 non-null       float64
#  10  cameraModel            0 non-null       float64
#  11  cameraDelay            0 non-null       float64
#  12  cameraHeight           0 non-null       float64
#  13  cameraDepth            0 non-null       float64
#  14  cameraTilt             0 non-null       float64
#  15  cameraHeading          0 non-null       float64
#  16  detectionDistance      0 non-null       float64
#  17  timestampIssues        0 non-null       float64
#  18  baitUse                0 non-null       float64
#  19  featureType            0 non-null       float64
#  20  habitat                0 non-null       float64
#  21  deploymentGroups       0 non-null       float64
#  22  deploymentTags         0 non-null       object
#  23  deploymentComments     0 non-null       object
#  24  mediaID                229286 non-null  object
#  25  captureMethod          0 non-null       float64
#  26  timestamp              229282 non-null  object
#  27  filePath               229286 non-null  object
#  28  filePublic             229286 non-null  bool
#  29  fileName               229286 non-null  object
#  30  fileMediatype          229286 non-null  object
#  31  exifData               156284 non-null  object
#  32  favorite               229286 non-null  bool
#  33  mediaComments          142 non-null     object
# dtypes: bool(2), float64(19), object(13)
# memory usage: 56.4+ MB

# %%
merged_df.head(1)
# Out:
#                deploymentID locationID locationName  latitude  longitude  \
# 0  66e5dee8f8e217337ca907a5        NaN          NaN       NaN        NaN
#
#    coordinateUncertainty  deploymentStart  deploymentEnd setupBy  cameraID  \
# 0                    NaN              NaN            NaN     NaN       NaN
#
#    ...                           mediaID  captureMethod             timestamp  \
# 0  ...  c112813a5f3b9cec26f95fad982b8d09            NaN  2024-01-24T18:56:50Z
#
#                                             filePath  filePublic  \
# 0  https://urbanriverrangers.s3.amazonaws.com/ima...        True
#
#        fileName  fileMediatype  \
# 0  SYFW0001.JPG     image/jpeg
#
#                                             exifData  favorite  mediaComments
# 0  {"Make": "TC", "Model": "XG2", "Software": "R2...     False            NaN
#
# [1 rows x 34 columns]
